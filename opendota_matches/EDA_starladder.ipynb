# %%
import os
import copy
import config
import matplotlib.pyplot as plt
# %matplotlib inline

import json
import requests
import pandas as pd
from pandas.io.json import json_normalize 
# 
# hero_id = json.load(input_file)
# input_file.close()
# print('hero_id')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-bd0f407c26e8> in <module>
#       1 import os
#       2 import copy
# ----> 3 import config
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'config'

# %%
# align dataframe center
<style scoped> .dataframe tbody tr th:only-of-type { vertical-align: middle; }
    
.dataframe tbody tr th {
    vertical-align: top;
}

.dataframe thead th {
    text-align: right;
}
# Out:
#   File "<ipython-input-16-ba0bc4ec18b3>", line 2
#     <style scoped> .dataframe tbody tr th:only-of-type { vertical-align: middle; }
#     ^
# SyntaxError: invalid syntax

# %%
input_file = open('matches/league_id_10979_starladder_s2_matchdata.json') 
data = json.load(input_file)
input_file.close()

# %%
heroes_df = pd.read_json('opendota_api_constants/heroes.json')
#heroes = open('opendota_api_constants/heroes.json')
heroes_df
# Out:
#       id                               name       localized_name primary_attr  \
# 0      1             npc_dota_hero_antimage            Anti-Mage          agi
# 1      2                  npc_dota_hero_axe                  Axe          str
# 2      3                 npc_dota_hero_bane                 Bane          int
# 3      4          npc_dota_hero_bloodseeker          Bloodseeker          agi
# 4      5       npc_dota_hero_crystal_maiden       Crystal Maiden          int
# 5      6          npc_dota_hero_drow_ranger          Drow Ranger          agi
# 6      7          npc_dota_hero_earthshaker          Earthshaker          str
# 7      8           npc_dota_hero_juggernaut           Juggernaut          agi
# 8      9               npc_dota_hero_mirana               Mirana          agi
# 9     10            npc_dota_hero_morphling            Morphling          agi
# 10    11            npc_dota_hero_nevermore         Shadow Fiend          agi
# ...

# %%
heroes_dict = {}
for i in range (len(heroes['heroes'])):
    hero_id = heroes['heroes'][i]['id']
    hero_name = heroes['heroes'][i]['localized_name']
    heroes_dict[hero_id]= hero_name
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'heroes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-ac47b90c0c9f> in <module>
#       1 #heroes_dict = {}
# ...

# %%
big_df = json_normalize(data)
big_df.shape
# Out:
# (153, 2580)

# %%
big_df.head(1)
# Out:
#      match_id  barracks_status_dire  barracks_status_radiant  \
# 0  4833593109                     0                       51
#
#                                                 chat  cluster  dire_score  \
# 0  [{'time': -80, 'type': 'chatwheel', 'key': '37...      133          55
#
#    dire_team_id                                      draft_timings  duration  \
# 0       7118032  [{'order': 1, 'pick': False, 'active_team': 2,...      4036
#
#    engine  first_blood_time  game_mode  human_players  leagueid  lobby_type  \
# 0       1                60          2             10     10979           1
#
#    match_seq_num  negative_votes  \
# 0     4062972494              34
#
#                                           objectives  \
# 0  [{'time': 61, 'type': 'CHAT_MESSAGE_FIRSTBLOOD...
#
#                                           picks_bans  positive_votes  \
# 0  [{'is_pick': False, 'hero_id': 38, 'team': 0, ...             314
#
# ...

# %%
big_df.describe()
# Out:
#            match_id  barracks_status_dire  barracks_status_radiant  \
# count  1.530000e+02            153.000000               153.000000
# mean   4.793275e+09             44.882353                44.111111
# std    2.885193e+07             23.633980                26.305532
# min    4.770332e+09              0.000000                 0.000000
# 25%    4.773109e+09             32.000000                12.000000
# 50%    4.777644e+09             52.000000                63.000000
# 75%    4.833593e+09             63.000000                63.000000
# max    4.844548e+09             63.000000                63.000000
#
#           cluster  dire_score  dire_team_id     duration  engine  \
# count  153.000000  153.000000  1.530000e+02   153.000000   153.0
# mean   160.470588   23.104575  4.177317e+06  2110.797386     1.0
# std     43.406897   11.042480  3.024704e+06   596.350715     0.0
# min    121.000000    3.000000  3.000000e+00   806.000000     1.0
# ...

# %%
big_df['series_type'].value_counts()
# Out:
# 1    145
# 2      6
# 0      2
# Name: series_type, dtype: int64

# %%
# CANT DO THIS --> NNED TO FILTER OUT CHATWHEEL AND COSMETICS STUFF BY NAME FIRST 
m_df = big_df.iloc[:,0:40]
m_df.head(20, ASC=False)
# Out:
#       match_id  barracks_status_dire  barracks_status_radiant  \
# 0   4833593109                     0                       51
# 1   4774328947                    15                       50
# 2   4779407768                    48                       63
# 3   4833371463                     0                       48
# 4   4833120790                    63                       51
# 5   4835973421                    15                        0
# 6   4835092211                     3                       63
# 7   4778183525                     0                        3
# 8   4835349235                    63                        0
# 9   4780631882                    63                       48
# 10  4844403184                    31                        0
# 11  4777644210                    51                        0
# 12  4838510531                     0                       31
# 13  4779969700                     3                        3
# ...

# %%
# Filter columns for overview df
# Will have a picks_ban df 

cfilter =[
'match_id',
 'barracks_status_dire',
 'barracks_status_radiant',
 'dire_score',
 'dire_team_id',
 'draft_timings',
 'duration',
 'first_blood_time',
 'leagueid',
 'match_seq_num',
 'objectives',
 'picks_bans',
 'radiant_gold_adv',
 'radiant_score',
 'radiant_team_id',
 'radiant_win',
 'radiant_xp_adv',
 'skill',
 'start_time',
 'teamfights',
 'tower_status_dire',
 'tower_status_radiant',
 'version',
 'replay_salt',
 'series_id',
 'series_type',
 'players',
 'patch',
 'region',
 'throw',
 'loss',
 'replay_url'
]

# %%
list(big_df.columns)
# Out:
# ['match_id',
#  'barracks_status_dire',
#  'barracks_status_radiant',
#  'chat',
#  'cluster',
#  'dire_score',
#  'dire_team_id',
#  'draft_timings',
#  'duration',
#  'engine',
#  'first_blood_time',
#  'game_mode',
#  'human_players',
#  'leagueid',
#  'lobby_type',
#  'match_seq_num',
#  'negative_votes',
#  'objectives',
#  'picks_bans',
#  'positive_votes',
#  'radiant_gold_adv',
#  'radiant_score',
#  'radiant_team_id',
#  'radiant_win',
#  'radiant_xp_adv',
#  'skill',
#  'start_time',
#  'teamfights',
#  'tower_status_dire',
#  'tower_status_radiant',
#  'version',
#  'replay_salt',
#  'series_id',
#  'series_type',
#  'players',
#  'patch',
#  'region',
#  'throw',
#  'loss',
#  'replay_url',
#  'cosmetics.4640',
#  'cosmetics.4940',
#  'cosmetics.5105',
#  'cosmetics.5145',
#  'cosmetics.5594',
#  'cosmetics.5683',
#  'cosmetics.5684',
#  'cosmetics.5725',
#  'cosmetics.5726',
#  'cosmetics.5727',
#  'cosmetics.5728',
#  'cosmetics.5729',
#  'cosmetics.5730',
# ...
